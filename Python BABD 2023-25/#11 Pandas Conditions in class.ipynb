# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('tipsCC.csv')

# %%
data
# Out:
#      total_bill   tip  Gender smoker   day    time  size  PaymentID
# 0         16.99  1.01  Female     No   Sun  Dinner     2  438616059
# 1         10.34  1.66    Male     No   Sun  Dinner     3  435521079
# 2         21.01  3.50    Male     No   Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No   Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No   Sun  Dinner     4  439957563
# ..          ...   ...     ...    ...   ...     ...   ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  432834186
# 242       17.82  1.75    Male     No   Sat  Dinner     2  434954363
# 243       18.78  3.00  Female     No  Thur  Dinner     2  438291018
#
# [244 rows x 8 columns]

# %%
df = data

# %%
df[df.total_bill > 20]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# 5         25.29  4.71    Male     No  Sun  Dinner     4  430832367
# 7         26.88  3.12    Male     No  Sun  Dinner     4  439713582
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2  430471010
# 238       35.83  4.67  Female     No  Sat  Dinner     3  438433576
# 239       29.03  5.92    Male     No  Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  432834186
#
# [97 rows x 8 columns]

# %%
df[(df.total_bill > 20) & (df.day == 'Sun')]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# 5         25.29  4.71    Male     No  Sun  Dinner     4  430832367
# 7         26.88  3.12    Male     No  Sun  Dinner     4  439713582
# 11        35.26  5.00  Female     No  Sun  Dinner     4  433273817
# 15        21.58  3.92    Male     No  Sun  Dinner     2  436348584
# 44        30.40  5.60    Male     No  Sun  Dinner     4  433229483
# 46        22.23  5.00    Male     No  Sun  Dinner     2  432512755
# 47        32.40  6.00    Male     No  Sun  Dinner     4  438693150
# 48        28.55  2.05    Male     No  Sun  Dinner     3  432957981
# 52        34.81  5.20  Female     No  Sun  Dinner     4  435902396
# 54        25.56  4.34    Male     No  Sun  Dinner     4  432931977
# ...

# %%
df[(df.day == 'Sun') | (df.day == 'Sat')]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 0         16.99  1.01  Female     No  Sun  Dinner     2  438616059
# 1         10.34  1.66    Male     No  Sun  Dinner     3  435521079
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3  438433576
# 239       29.03  5.92    Male     No  Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  432834186
# 242       17.82  1.75    Male     No  Sat  Dinner     2  434954363
#
# [163 rows x 8 columns]

# %%
df[(df.total_bill > 20) & ((df.day == 'Sun') | (df.day == 'Sat'))]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# 5         25.29  4.71    Male     No  Sun  Dinner     4  430832367
# 7         26.88  3.12    Male     No  Sun  Dinner     4  439713582
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2  430471010
# 238       35.83  4.67  Female     No  Sat  Dinner     3  438433576
# 239       29.03  5.92    Male     No  Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  432834186
#
# [75 rows x 8 columns]

# %%
#fetching all the records where total_bill <=20 and dat is Sunday or Sunday
#tilda ~ is used to retrun the reverse of what the command has stated

df[~(df.total_bill > 20) & ((df.day == 'Sun') | (df.day == 'Sat'))]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 0         16.99  1.01  Female     No  Sun  Dinner     2  438616059
# 1         10.34  1.66    Male     No  Sun  Dinner     3  435521079
# 6          8.77  2.00    Male     No  Sun  Dinner     2  432653358
# 8         15.04  1.96    Male     No  Sun  Dinner     2  432880148
# 9         14.78  3.23    Male     No  Sun  Dinner     2  437860007
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 233       10.77  1.47    Male     No  Sat  Dinner     2  436727329
# 234       15.53  3.00    Male    Yes  Sat  Dinner     2  439430460
# 235       10.07  1.25    Male     No  Sat  Dinner     2  430054733
# 236       12.60  1.00    Male    Yes  Sat  Dinner     2  432716346
# 242       17.82  1.75    Male     No  Sat  Dinner     2  434954363
#
# [88 rows x 8 columns]

# %%
#Fetch all the records for which transaction is done on sat or sun

df['day'].isin(['Sat','Sun'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 239     True
# 240     True
# 241     True
# 242     True
# 243    False
# Name: day, Length: 244, dtype: bool

# %%
df[df['day'].isin(['Sat','Sun'])]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 0         16.99  1.01  Female     No  Sun  Dinner     2  438616059
# 1         10.34  1.66    Male     No  Sun  Dinner     3  435521079
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3  438433576
# 239       29.03  5.92    Male     No  Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  432834186
# 242       17.82  1.75    Male     No  Sat  Dinner     2  434954363
#
# [163 rows x 8 columns]

# %%
cond1 = df['day'].isin(['Sat','Sun'])
cond2 = df.total_bill>20

# %%
df[cond1 & cond2]
# Out:
#      total_bill   tip  Gender smoker  day    time  size  PaymentID
# 2         21.01  3.50    Male     No  Sun  Dinner     3  432425804
# 3         23.68  3.31    Male     No  Sun  Dinner     2  430730025
# 4         24.59  3.61  Female     No  Sun  Dinner     4  439957563
# 5         25.29  4.71    Male     No  Sun  Dinner     4  430832367
# 7         26.88  3.12    Male     No  Sun  Dinner     4  439713582
# ..          ...   ...     ...    ...  ...     ...   ...        ...
# 237       32.83  1.17    Male    Yes  Sat  Dinner     2  430471010
# 238       35.83  4.67  Female     No  Sat  Dinner     3  438433576
# 239       29.03  5.92    Male     No  Sat  Dinner     3  430525394
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2  430257652
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2  432834186
#
# [75 rows x 8 columns]

# %%
def last_3(num):
    return str(num)[-3:]

# %%
last_3(10)
# Out:
# '10'

# %%
last_3(df.PaymentID)
# Out:
# 't64'

# %%
last_3(df['PaymentID'][0])
# Out:
# '059'

# %%
df['PaymentID'][0]
# Out:
# 438616059

# %%
df['last_3'] = df['PaymentID'].apply(last_3)

# %%
df
# Out:
#      total_bill   tip  Gender smoker   day    time  size  PaymentID last_3
# 0         16.99  1.01  Female     No   Sun  Dinner     2  438616059    059
# 1         10.34  1.66    Male     No   Sun  Dinner     3  435521079    079
# 2         21.01  3.50    Male     No   Sun  Dinner     3  432425804    804
# 3         23.68  3.31    Male     No   Sun  Dinner     2  430730025    025
# 4         24.59  3.61  Female     No   Sun  Dinner     4  439957563    563
# ..          ...   ...     ...    ...   ...     ...   ...        ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  430525394    394
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  430257652    652
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  432834186    186
# 242       17.82  1.75    Male     No   Sat  Dinner     2  434954363    363
# 243       18.78  3.00  Female     No  Thur  Dinner     2  438291018    018
#
# [244 rows x 9 columns]

# %%
def currency_symb(price):
    if price < 10:
        return '$'
    elif price >=10 and price <=30:
        return '$$'
    else:
        return '$$$'

# %%
df['Expense_Type'] = df['total_bill'].apply(currency_symb)

# %%
df
# Out:
#      total_bill   tip  Gender smoker   day    time  size  PaymentID last_3  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2  438616059    059
# 1         10.34  1.66    Male     No   Sun  Dinner     3  435521079    079
# 2         21.01  3.50    Male     No   Sun  Dinner     3  432425804    804
# 3         23.68  3.31    Male     No   Sun  Dinner     2  430730025    025
# 4         24.59  3.61  Female     No   Sun  Dinner     4  439957563    563
# ..          ...   ...     ...    ...   ...     ...   ...        ...    ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3  430525394    394
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2  430257652    652
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2  432834186    186
# 242       17.82  1.75    Male     No   Sat  Dinner     2  434954363    363
# 243       18.78  3.00  Female     No  Thur  Dinner     2  438291018    018
#
#     Expense_Type
# 0             $$
# 1             $$
# ...

# %%
my_quote = input('Enter your quote: ')
# Out:
# Enter your quote: A friend in need is a friend indeed

# %%
my_quote
# Out:
# 'A friend in need is a friend indeed'

# %%
my_quote = my_quote.upper()

# %%
my_quote.split()
# Out:
# ['A', 'FRIEND', 'IN', 'NEED', 'IS', 'A', 'FRIEND', 'INDEED']

# %%
my_list1 = my_quote.split()

# %%
my_list1
# Out:
# ['A', 'FRIEND', 'IN', 'NEED', 'IS', 'A', 'FRIEND', 'INDEED']

# %%
list(my_list1)
# Out:
# ['A', 'FRIEND', 'IN', 'NEED', 'IS', 'A', 'FRIEND', 'INDEED']

# %%
my_list1
# Out:
# ['A', 'FRIEND', 'IN', 'NEED', 'IS', 'A', 'FRIEND', 'INDEED']

# %%
newlist = [x for x in my_list1 if len(my_list1[x])>3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-65-723556ef24a4> in <module>
# ----> 1 newlist = [x for x in my_list1 if len(my_list1[x])>3]
#
# <ipython-input-65-723556ef24a4> in <listcomp>(.0)
# ----> 1 newlist = [x for x in my_list1 if len(my_list1[x])>3]
#
# TypeError: list indices must be integers or slices, not str

# %%
len(my_list1[x])>3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-64-455121a4b992> in <module>
# ----> 1 len(my_list1[x])>3
#
# NameError: name 'x' is not defined

# %%
str1 = input('Quotes: ')

mylist = str1.split(" ")

my_list2 = [item.upper() for item in my_list1 if len(item) > 3]

my_list2.sort(key = len)

my_list3 = [item.replace('.','') for item in my_list2]

print(str1, my_list1, my_list2, my_list3, sep = '\n' )
# Out:
# Quotes: A friend in need is a friend indeed
# A friend in need is a friend indeed
# ['A', 'FRIEND', 'IN', 'NEED', 'IS', 'A', 'FRIEND', 'INDEED']
# ['NEED', 'FRIEND', 'FRIEND', 'INDEED']
# ['NEED', 'FRIEND', 'FRIEND', 'INDEED']
